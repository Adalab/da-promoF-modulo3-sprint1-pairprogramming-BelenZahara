# %% [markdown]
# # Ejercicios Pair M3L4 Union Datos

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# Carga ambos conjuntos de datos en pandas DataFrames

# %%
df_1 = pd.read_csv("world-data-2023_part1.csv", index_col=0)
df_2 = pd.read_csv("world-data-2023_part2.csv", index_col=0)

# %% [markdown]
# Explora los conjuntos de datos

# %%
df_1.head()
#df_2.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# ...

# %% [markdown]
# Identifica las columnas comunes entre los dos conjuntos de datos

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GDP                                        193 non-null    object
#  1   Gross primary education enrollment (%)     188 non-null    object
#  2   Gross tertiary education enrollment (%)    183 non-null    object
#  3   Infant mortality                           189 non-null    float64
#  4   Largest city                               189 non-null    object
#  5   Life expectancy                            187 non-null    float64
#  6   Maternal mortality ratio                   181 non-null    float64
#  7   Minimum wage                               150 non-null    object
#  8   Official language                          190 non-null    object
#  9   Out of pocket health expenditure           188 non-null    object
# ...

# %%
# La única columna en común es country/Country aunque una empieza por mayúscula y la otra no

# %% [markdown]
# Utiliza el método de unión de Pandas que consideres más adecuado para combinar los datos de ambos años en un solo DataFrame

# %%
df_mergeado = df_1.merge(df_2, how = "inner", on =None, left_on="Country", right_on="country")

# %%
df_mergeado
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# Explica por qué elegiste ese método de unión y cómo se llevaron a cabo los pasos anteriores

# %%
# Hemos elegido .merge() porque permite unir los DF por una columna en común, que en este caso es country/Country, ya que tiene los mismos valores aunque los encabezamos no coincidan al 100%

# %% [markdown]
# ## Ejercicios de limpieza

# %% [markdown]
# 1. Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %%
df_mergeado.drop(columns=['country'], inplace=True)

# %% [markdown]
# 2. Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
# - No tengan espacios.
# - Estén en minúscula.
# - No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
# - Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
# - Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
df_mergeado.columns
#df_mar.rename(columns = {"id_": "ID"}, inplace = True )
df_final = df_mergeado.copy()
df_final.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price              GDP  \
# 0            4.47             2.10%          0.70   19,101,353,833
# 1            1.62            28.10%          1.36   15,278,077,447
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
#
# ...

# %%
# vamos a iterar por todas las columnas del DataFrame y a cada una de ellas la pondremos en minúsula y le aplicaremos un replace para quitar los puntos. 
nuevas_columnas = {columna: columna.lower().replace(" ", "").replace("\n","").replace("(%)","").replace("(km2)","").replace("(p/km2)","").replace(":","") for columna in df_final.columns}

# comprobamos que hemos creado el diccionario correctamente
nuevas_columnas
df_final.rename(columns = nuevas_columnas, inplace = True)

# comprobamos que se han cambiado los nombres de las columnas
df_final.head()
df_final.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'coordinates', 'latitud',
#        'longitud'],
#       dtype='object')

# %% [markdown]
# 3. La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.

# %%
df_mergeado["coordinates"].str.split(",", expand = True)
# Out:
#                   0               1
# 0      ('33.93911 '    '67.709953')
# 1     ('41.153332 '    '20.168331')
# 2     ('28.033886 '     '1.659626')
# 3     ('42.506285 '     '1.521801')
# 4    ('-11.202692 '    '17.873887')
# ..              ...             ...
# 190     ('6.42375 '    '-66.58973')
# 191   ('14.058324 '   '108.277199')
# 192   ('15.552727 '    '48.516388')
# 193  ('-13.133897 '    '27.849332')
# 194  ('-19.015438 '    '29.154857')
#
# [195 rows x 2 columns]

# %%
df_mergeado[["latitud", "longitud"]]= df_mergeado["coordinates"].str.split(",", expand = True)

# %%
df_mergeado
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# 4. Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.

# %%
df_copia_mergeado.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population',
#        'coordinates', 'latitud', 'longitud'],
#       dtype='object')

# %%
df_copia_mergeado = df_mergeado.copy()



columnas= ['Unemployment rate', 'Total tax rate', 'Tax revenue (%)','Gross tertiary education enrollment (%)' ,'Population: Labor force participation (%)', 'Out of pocket health expenditure', 'Gross primary education enrollment (%)', 'Forested Area (%)', 'CPI Change (%)', 'Agricultural Land( %)']
for columna in columnas:
    df_copia_mergeado[columna] =df_copia_mergeado[columna].str.replace("%", "")

# %%
df_copia_mergeado.sample(5)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 164        Spain               94           ES                 52.60
# 28   Ivory Coast               83           CI                 64.80
# 87    Kazakhstan                7           KZ                 80.40
# 144       Rwanda              525           RW                 73.40
# 77         India              464           IN                 60.40
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 164        505,370           196,000        7.90          34.0
# 28         322,463            27,000       35.74         225.0
# 87       2,724,900            71,000       21.77           7.0
# 144         26,338            35,000       31.70         250.0
# 77       3,287,263         3,031,000       17.86          91.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 164             Madrid       244,002  110.96           0.70           EUR
# ...

# %% [markdown]
# 5. Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$".

# %%
columna_moneda = ["Gasoline Price", "GDP", "Minimum wage"]

for columna in columna_moneda:
    df_copia_mergeado[columna] =df_copia_mergeado[columna].str.replace("$", "")
# Out:
# /var/folders/vc/6zzvx8k5237dtyhf94hsl1580000gp/T/ipykernel_15013/863105538.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copia_mergeado[columna] =df_copia_mergeado[columna].str.replace("$", "")

# %%
df_copia_mergeado
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                 58.10
# 1        Albania              105           AL                 43.10
# 2        Algeria               18           DZ                 17.40
# 3        Andorra              164           AD                 40.00
# 4         Angola               26           AO                 47.50
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                 24.50
# 191      Vietnam              314           VN                 39.30
# 192        Yemen               56           YE                 44.60
# 193       Zambia               25           ZM                 32.10
# 194     Zimbabwe               38           ZW                 41.90
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# 6. Guarda el DataFrame para usarlo en el pairprogramming de mañana.

# %%
df_copia_mergeado.to_csv("Data_frame_listo_para_usar.csv")

# %% [markdown]
# ## Ejercicios de filtrado

# %% [markdown]
# 1. Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.

# %%
df_mergeado[df_mergeado["Infant mortality"].between(40,50, inclusive="both")][["Country", "Infant mortality"]]
# Out:
#           Country  Infant mortality
# 0     Afghanistan              47.9
# 26   Burkina Faso              49.0
# 27        Burundi              41.0
# 47       Djibouti              49.8
# 72          Haiti              49.5
# 89       Kiribati              41.2
# 125         Niger              48.0
# 166         Sudan              42.1
# 175          Togo              47.4
# 192         Yemen              42.9
# 193        Zambia              40.4

# %% [markdown]
# 2. Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.

# %%
df_mergeado.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population',
#        'coordinates', 'latitud', 'longitud'],
#       dtype='object')

# %%
df_mergeado[(df_mergeado["Fertility Rate"] >= 20) & df_mergeado['Life expectancy'] > 75][["Country","Fertility Rate",'Life expectancy']]
# Out:
# Empty DataFrame
# Columns: [Country, Fertility Rate, Life expectancy]
# Index: []

# %% [markdown]
# 3. Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.

# %%
df_mergeado[df_mergeado['Capital/Major City'].str.contains('la', case=False, regex = True, na = False)][["Capital/Major City"]]
# Out:
#     Capital/Major City
# 3     Andorra la Vella
# 53              Malabo
# 68      Guatemala City
# 103       Kuala Lumpur
# 114        Ulaanbaatar
# 131          Islamabad
# 138             Manila
# 157         Bratislava
# 182            Kampala
# 189          Port Vila

# %% [markdown]
# 4. Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.

# %%
df_mergeado[(df_mergeado['Physicians per thousand'] > 5)][["Country","Physicians per thousand"]]
# Out:
#         Country  Physicians per thousand
# 9       Austria                     5.17
# 15      Belarus                     5.19
# 42         Cuba                     8.42
# 63      Georgia                     7.12
# 66       Greece                     5.48
# 99    Lithuania                     6.35
# 113      Monaco                     6.56
# 140    Portugal                     5.12
# 149  San Marino                     6.11
# 187     Uruguay                     5.05

# %% [markdown]
# 5. Encuentra los países cuya tasa de fertilidad sea mayor a 6.

# %%
df_mergeado[(df_mergeado['Fertility Rate']> 6)][["Country","Fertility Rate"]]
# Out:
#      Country  Fertility Rate
# 125    Niger            6.91
# 160  Somalia            6.07

# %% [markdown]
# 6. Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.

# %%
df_mergeado[(df_mergeado['Currency-Code']=='EUR')][["Country","Currency-Code"]]
# Out:
#                  Country Currency-Code
# 3                Andorra           EUR
# 9                Austria           EUR
# 16               Belgium           EUR
# 43                Cyprus           EUR
# 55               Estonia           EUR
# 59               Finland           EUR
# 60                France           EUR
# 64               Germany           EUR
# 66                Greece           EUR
# 73          Vatican City           EUR
# 81   Republic of Ireland           EUR
# 83                 Italy           EUR
# 93                Latvia           EUR
# 99             Lithuania           EUR
# 100           Luxembourg           EUR
# 106                Malta           EUR
# 113               Monaco           EUR
# 115           Montenegro           EUR
# 140             Portugal           EUR
# 149           San Marino           EUR
# 157             Slovakia           EUR
# 158             Slovenia           EUR
# 164                Spain           EUR

# %% [markdown]
# 7. Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70.

# %%
df_mergeado[(df_mergeado["Infant mortality"] > 70)][["Country", "Infant mortality"]]
# Out:
#                       Country  Infant mortality
# 33   Central African Republic              84.5
# 34                       Chad              71.4
# 126                   Nigeria              75.7
# 155              Sierra Leone              78.5
# 160                   Somalia              76.6
